# %% [markdown]
# # Download dos dados do Fogo Cruzado
#
# Este notebook apenas executa o script `02_baixar_fogo_cruzado.py`, que faz a
# consulta direta a API oficial do Fogo Cruzado e grava o recorte bruto usado
# na etapa seguinte do tratamento.

# %%
from pathlib import Path
import runpy

diretorio = Path.cwd().resolve()
if diretorio.name == "01_preparacao_dados":
    script = diretorio / "02_baixar_fogo_cruzado.py"
else:
    script = diretorio / "01_preparacao_dados" / "02_baixar_fogo_cruzado.py"

runpy.run_path(str(script), run_name="__main__")
